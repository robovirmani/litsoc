# %%
import pandas as pd

# %%
patiala = pd.read_csv('patiala.txt', names = ['Area'])

# %%
patiala
# Out:
#                     Area
# 0           Sirhind Road
# 1                 Sanaur
# 2                Rajpura
# 3           Mehta Colony
# 4              Moti Bagh
# 5           Bhadson Road
# 6              SST Nagar
# 7   Devigarh-Pehowa Road
# 8            Anand Nagar
# 9        Century Enclave
# 10   New Officers Colony
# 11          Rattan Nagar
# 12          Baneda Khurd
# 13               Tripuri
# 14            Nabha Road
# 15             Shekhpura
# 16          Lehal Colony
# 17          Urban Estate
# 18                 Baran
# 19          Ghuman Nagar
# 20        Dashmesh Nagar
# 21            Ajit Nagar
# 22            Prem Nagar
# 23          Ranjit Nagar
# 24               Asarpur
# 25           Charan Bagh
# 26         Sullar Colony
# 27      Majathia Enclave
# 28       Dhaliwal Colony
# 29           Upkar Nagar
# ..                   ...
# 31    Hassanpur Prohotan
# 32                Patran
# 33           Bahadurgarh
# 34          Bishan Nagar
# 35         Gurbax Colony
# ...

# %%
for i in patiala:
    print(i)
# Out:
# Area

# %%
for i in patiala.Area:
    print(i)
# Out:
# Sirhind Road
# Sanaur
# Rajpura
# Mehta Colony
# Moti Bagh
# Bhadson Road
# SST Nagar
# Devigarh-Pehowa Road
# Anand Nagar
# Century Enclave
# New Officers Colony
# Rattan Nagar
# Baneda Khurd
# Tripuri
# Nabha Road
# Shekhpura
# Lehal Colony
# Urban Estate
# Baran
# Ghuman Nagar
# Dashmesh Nagar
# Ajit Nagar
# Prem Nagar
# Ranjit Nagar
# Asarpur
# Charan Bagh
# Sullar Colony
# Majathia Enclave
# Dhaliwal Colony
# Upkar Nagar
# Guru Nanak Nagar
# Hassanpur Prohotan
# Patran
# Bahadurgarh
# Bishan Nagar
# Gurbax Colony
# Gurmat Colony
# Ram Nagar
# Lahori Gate
# Arya Samaj
# Hardaspur
# Sunny Enclave
# Baradari
# Harinder Nagar
# Model Town
# Lower Mall
# Aman Nagar
# Jalalpur
# Keshar Bagh
# Heera Bagh
# Mathura Colony
# Dakala Road
# Seona
# Samana
# Nabha
# Balbehra
# Sarabha Nagar
# Bagichi Het Ram
# Bhakhra Enclave
# Markal Colony
# Professor Colony
